# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

KM_8 = KMeans(n_clusters=8).fit(X)
y_KM_8_pred = KM_8.predict(X)

# %%
print(f'KM_8 Silhouette Score: {silhouette_score(X, y_KM_8_pred)}')
# Out:
# KM_8 Silhouette Score: 0.5486213604076143

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
KM_5 = KMeans(n_clusters=5).fit(X)
y_KM_5_pred = KM_5.predict(X)

# %%
print(f'KM_5 Silhouette Score: {silhouette_score(X, y_KM_5_pred)}')
# Out:
# KM_5 Silhouette Score: 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
KM_3 = KMeans(n_clusters=3).fit(X)
y_KM_3_pred = KM_3.predict(X)

# %%
print(f'KM_3 Silhouette Score: {silhouette_score(X, y_KM_3_pred)}')
# Out:
# KM_3 Silhouette Score: 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import KElbowVisualizer
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
#Distortion (Default)

KM_d = KMeans()
vis_d = KElbowVisualizer(KM_d, k=(5,10)) 
vis_d.fit(X)
vis_d.poof();
# Out:
# /usr/local/lib/python3.7/site-packages/yellowbrick/utils/kneed.py:140: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# /usr/local/lib/python3.7/site-packages/yellowbrick/cluster/elbow.py:343: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)

# %%
#Silhouette

KM_s = KMeans()
vis_s = KElbowVisualizer(KM_s, metric = 'silhouette', k=(5,10)) 
vis_s.fit(X)
vis_s.poof();

# %%
#Calinski-Harabasz

KM_c = KMeans()
vis_c = KElbowVisualizer(KM_c, metric = 'calinski_harabasz', k=(5,10)) 
vis_c.fit(X)
vis_c.poof();
# Out:
# /usr/local/lib/python3.7/site-packages/yellowbrick/utils/kneed.py:140: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# /usr/local/lib/python3.7/site-packages/yellowbrick/cluster/elbow.py:343: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
from sklearn import cluster, datasets

AggC_8 = cluster.AgglomerativeClustering(n_clusters=8, linkage='single').fit(X)
y_AggC_8 = AggC_8.labels_.astype(np.int)

print(f'AggC_8 Silhouette Score: {silhouette_score(X, y_AggC_8)}')
# Out:
# AggC_8 Silhouette Score: 0.4231857440030851

# %%
AggC_5 = cluster.AgglomerativeClustering(n_clusters=5, linkage='single').fit(X)
y_AggC_5 = AggC_5.labels_.astype(np.int)

print(f'AggC_5 Silhouette Score: {silhouette_score(X, y_AggC_5)}')
# Out:
# AggC_5 Silhouette Score: -0.0262784249916707

# %%
AggC_3 = cluster.AgglomerativeClustering(n_clusters=3, linkage='single').fit(X)
y_AggC_3 = AggC_3.labels_.astype(np.int)

print(f'AggC_3 Silhouette Score: {silhouette_score(X, y_AggC_3)}')
# Out:
# AggC_3 Silhouette Score: 0.48798203351890657

# %%
# Todavía no me queda claro la diferencia entre una Silhouette Score negative y una positive. Bueno, resultaron un poco más bajas que con KMeans.

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
from sklearn.datasets import make_blobs

plt.figure(figsize=(10,10))
plt.scatter(np.array(X)[:,0], np.array(X)[:,1], c=y_KM_3_pred, cmap="Set3")

centroids = KM_3.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=100)

plt.show();

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA

pca_2 = PCA(n_components=2).fit(X)
pca_2_X = pca_2.transform(X)

KM_2 = KMeans(n_clusters=2)
KM_2.fit(pca_2_X)
y_pca_2_pred = KM_2.predict(pca_2_X)

plt.figure(figsize=(10,10))
plt.scatter(pca_2_X[:,0], pca_2_X[:,1], c=y_pca_2_pred, cmap="Set3")

centroids = KM_2.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=100)

plt.show();

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
from sklearn.manifold import TSNE

fig, ax = plt.subplots(1, 4, figsize=(10, 10))
for i, perp in enumerate([25, 50, 75, 100]):
    tsne = TSNE(perplexity = perp)
    x_embedded = tsne.fit_transform(X)
    ax[i].scatter(x_embedded[:,0], x_embedded[:,1], c=y, cmap="Reds")
    ax[i].set_title(f'Perplexity = {perp}')
    
plt.show();
