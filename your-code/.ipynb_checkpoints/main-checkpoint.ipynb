# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
from sklearn.metrics import silhouette_score
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
kmeans = cluster.KMeans(n_clusters=8)
kmeans.fit(X)
# Out:
# KMeans()

# %%
y_pred = kmeans.predict(X)
silhouette_score(X, y_pred)
# Out:
# 0.5398971441034137

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans = cluster.KMeans(n_clusters=5)
kmeans.fit(X)
y_pred = kmeans.predict(X)
silhouette_score(X, y_pred)
# Out:
# 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans = cluster.KMeans(n_clusters=3)
kmeans.fit(X)
y_pred = kmeans.predict(X)
silhouette_score(X, y_pred)
# Out:
# 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import KElbowVisualizer

model = cluster.KMeans()
# default is distortion
visualizer = KElbowVisualizer(model, k=(3,12))
visualizer.fit(X)
visualizer.poof();

# %%
visualizer = KElbowVisualizer(model, k=(3,12), metric='calinski_harabasz', timings=False, locate_elbow=False)
visualizer.fit(X)
visualizer.poof();

# %%
visualizer = KElbowVisualizer(model, k=(3,12), metric='silhouette')
visualizer.fit(X)
visualizer.poof();

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
model = cluster.AgglomerativeClustering()
visualizer = KElbowVisualizer(model, k=(3,12))
visualizer.fit(X)
visualizer.poof();

# %%
visualizer = KElbowVisualizer(model, k=(3,12), metric='calinski_harabasz')
visualizer.fit(X)
visualizer.poof();

# %%
visualizer = KElbowVisualizer(model, k=(3,12), metric='silhouette')
visualizer.fit(X)
visualizer.poof();

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
kmeans = cluster.KMeans(n_clusters=4)
kmeans.fit(X)
y_pred = kmeans.predict(X)
centers = pd.DataFrame(data = kmeans.cluster_centers_, columns = cols)

# %%
import seaborn as sns

pp = X.copy()
pp['clusters'] = kmeans.labels_
sns.pairplot(pp, hue='clusters', kind='reg')

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

pca = PCA(n_components = 2)
pca_X = pca.fit_transform(scaled_X)

# %%
kmeans_pca = cluster.KMeans(n_clusters = 4)
kmeans_pca.fit(pca_X)
# Out:
# KMeans(n_clusters=4)

# %%
df_kmeans_pca = pd.concat([X.reset_index(drop = True), \
                          pd.DataFrame(pca_X, columns= ['PCA 1', 'PCA 2'])], axis = 1)

df_kmeans_pca['KMeans Clusters'] = kmeans_pca.labels_

df_kmeans_pca.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
# ...

# %%
plt.scatter(df_kmeans_pca['PCA 1'], df_kmeans_pca['PCA 2'], \
            c = df_kmeans_pca['KMeans Clusters'], cmap = 'rainbow')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.show()

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
from sklearn.manifold  import TSNE

fig, ax = plt.subplots(1,4,figsize=(15,7))
for i, perp in enumerate([5,30,50,100]):
    tsne=TSNE(perplexity=perp,random_state=123)
    x_unida=tsne.fit_transform(df_kmeans_pca[['PCA 1','PCA 2']])
    ax[i].scatter(x_unida[:,0],x_unida[:,1],c=df_kmeans_pca['KMeans Clusters'], cmap = 'rainbow')
    ax[i].set_title('Perplexity={}'.format(perp))
plt.show()
