# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters=8)
data_clusters = kmeans.fit(X)
score = silhouette_score(X, kmeans.labels_, metric='euclidean', sample_size=len(X))
print('Silhouette score =', score)
# Out:
# Silhouette score = 0.5398971441034137

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters=5)
data_clusters = kmeans.fit(X)
score = silhouette_score(X, kmeans.labels_, metric='euclidean', sample_size=len(X))
print('Silhouette score =', score)
# Out:
# Silhouette score = 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters=3)
data_clusters = kmeans.fit(X)
score = silhouette_score(X, kmeans.labels_, metric='euclidean', sample_size=len(X))
print('Silhouette score =', score)
# Out:
# Silhouette score = 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans

# %%
model = KMeans()
visualizer = KElbowVisualizer(model,metric = 'distortion')
visualizer.fit(X)
visualizer.poof();

# %%
model = KMeans()
visualizer = KElbowVisualizer(model,metric = 'silhouette')
visualizer.fit(X)
visualizer.poof();
# Out:
# /usr/local/Cellar/jupyterlab/2.2.9/libexec/lib/python3.9/site-packages/yellowbrick/utils/kneed.py:182: YellowbrickWarning: No "knee" or "elbow point" detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# /usr/local/Cellar/jupyterlab/2.2.9/libexec/lib/python3.9/site-packages/yellowbrick/utils/kneed.py:140: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# /usr/local/Cellar/jupyterlab/2.2.9/libexec/lib/python3.9/site-packages/yellowbrick/cluster/elbow.py:343: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, metric = 'calinski_harabasz')
visualizer.fit(X)
visualizer.poof();

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model = AgglomerativeClustering()
visualizer = KElbowVisualizer(model,metric = 'silhouette')
visualizer.fit(X)
visualizer.poof();

# %%
model = AgglomerativeClustering()
visualizer = KElbowVisualizer(model,metric = 'distortion')
visualizer.fit(X)
visualizer.poof();

# %%
model = AgglomerativeClustering()
visualizer = KElbowVisualizer(model, metric = 'calinski_harabasz')
visualizer.fit(X)
visualizer.poof();

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
import seaborn as sns

# %%
kmeans = cluster.KMeans(n_clusters=4)
kmeans.fit(X)
y_pred = kmeans.predict(X)
centers = pd.DataFrame(data = kmeans.cluster_centers_)

# %%
ex6 = X.copy()
ex6['k_clusters'] = kmeans.labels_
sns.set(rc={'figure.figsize':(30,30)})
sns.pairplot(ex6, hue='k_clusters')

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)
pca_da = pca.fit_transform(X)

data_pca = pd.DataFrame(data = pca_da, columns = ['pc_1', 'pc_2'])

# %%
pca_data= pd.DataFrame(data = pca.components_, columns = X.columns.values, index = ['pc_1', 'pc_2'])

# %%
pca_data
# Out:
#        alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# pc_1  0.001659   -0.000681  0.000195          -0.004671   0.017868
# pc_2  0.001203    0.002155  0.004594           0.026450   0.999344
#
#       total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# pc_1       0.000990    0.001567             -0.000123         0.000601
# pc_2       0.000878   -0.000052             -0.001354         0.005004
#
#       color_intensity       hue  od280/od315_of_diluted_wines   proline
# pc_1         0.002327  0.000171                      0.000705  0.999823
# pc_2         0.015100 -0.000763                     -0.003495 -0.017774

# %%
sns.scatterplot(data_pca['pc_1'],data_pca['pc_2'], hue = model.labels_)
# Out:
# /usr/local/Cellar/jupyterlab/2.2.9/libexec/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pc_1', ylabel='pc_2'>

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
from sklearn.manifold import TSNE

X, y = datasets.load_iris(return_X_y=True)

fig, ax = plt.subplots(1, 4, figsize=(15, 7))
for i, perp in enumerate([5, 30, 50, 100]):
    tsne = TSNE(perplexity=perp)
    x_embedded = tsne.fit_transform(X)
    ax[i].scatter(x_embedded[:, 0], x_embedded[:, 1], c=y)
    ax[i].set_title("Perplexity = {}".format(perp))
    
plt.show();
