# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import metrics
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import AgglomerativeClustering

# %%
data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters = 8)
kmeans.fit(X)
score = metrics.silhouette_score(X, kmeans.labels_, metric = 'euclidean', sample_size = len(X))

print(f'Silhouette Score = {score}')
# Out:
# Silhouette Score = 0.5398971441034137

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters = 5)
kmeans.fit(X)
score = metrics.silhouette_score(X, kmeans.labels_, metric = 'euclidean', sample_size = len(X))

print(f'Silhouette Score = {score}')
# Out:
# Silhouette Score = 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters = 3)
kmeans.fit(X)
score = metrics.silhouette_score(X, kmeans.labels_, metric = 'euclidean', sample_size = len(X))

print(f'Silhouette Score = {score}')
# Out:
# Silhouette Score = 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
model = KMeans()
plt.figure(figsize = (16, 8))
visualizer = KElbowVisualizer(model, k = (3,12), metric = 'distortion')
visualizer.fit(X)
visualizer.poof();

# %%
model = KMeans()
plt.figure(figsize = (16, 8))
visualizer = KElbowVisualizer(model, k = (3,12), metric = 'silhouette')
visualizer.fit(X)
visualizer.poof();

# %%
model = KMeans()
plt.figure(figsize = (16, 8))
visualizer = KElbowVisualizer(model, k = (3,12), metric = 'calinski_harabasz')
visualizer.fit(X)
visualizer.poof();

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
model = AgglomerativeClustering()
plt.figure(figsize = (16, 8))
visualizer = KElbowVisualizer(model, k = (3,12), metric = 'calinski_harabasz')
visualizer.fit(X)
visualizer.poof();

# %%
model = AgglomerativeClustering()
plt.figure(figsize = (16, 8))
visualizer = KElbowVisualizer(model, k = (3,12), metric = 'silhouette')
visualizer.fit(X)
visualizer.poof();

# %%
model = AgglomerativeClustering()
plt.figure(figsize = (16, 8))
visualizer = KElbowVisualizer(model, k = (3,12), metric = 'distortion')
visualizer.fit(X)
visualizer.poof();

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
model = KMeans(n_clusters = 6)
model.fit(X)

X['clusters'] = model.labels_

# %%
sns.distributions._has_statsmodels = True

# %%
sns.pairplot(data = X, kind = 'scatter', hue = 'clusters', palette = 'Set2', diag_kws = {'bw':0.1})

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
X2 = X.drop('clusters', axis = 1)

pca = PCA(n_components = 2)
pca_data = pca.fit_transform(X2)

df_pca = pd.DataFrame(data = pca_data, columns = ['principal_component_1', 'principal_component_2'])

# %%
df_pca_comp = pd.DataFrame(data = pca.components_, columns = X2.columns.values, index = ['principal_component_1', 'principal_component2'])
df_pca_comp
# Out:
#                         alcohol  malic_acid       ash  alcalinity_of_ash  \
# principal_component_1  0.001659   -0.000681  0.000195          -0.004671
# principal_component2   0.001203    0.002155  0.004594           0.026450
#
#                        magnesium  total_phenols  flavanoids  \
# principal_component_1   0.017868       0.000990    0.001567
# principal_component2    0.999344       0.000878   -0.000052
#
#                        nonflavanoid_phenols  proanthocyanins  color_intensity  \
# principal_component_1             -0.000123         0.000601         0.002327
# principal_component2              -0.001354         0.005004         0.015100
#
#                             hue  od280/od315_of_diluted_wines   proline
# principal_component_1  0.000171                      0.000705  0.999823
# principal_component2  -0.000763                     -0.003495 -0.017774

# %%
plt.figure(figsize = (16, 8))
sns.scatterplot(x = df_pca['principal_component_1'], y = df_pca['principal_component_2'], palette = 'Set2', hue = model.labels_)
# Out:
# <AxesSubplot:xlabel='principal_component_1', ylabel='principal_component_2'>

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
colours = ['green', 'blue', 'purple', 'orange', 'yellow', 'red']
color_asign = []
# para cada valor d clustter
for row in model.labels_:
    color_asign.append(colours[row % len(colours)])


fig, ax = plt.subplots(1, 4, figsize = (16, 8))
for i, perp in enumerate([5, 30, 50, 100]):
    tsne = TSNE(perplexity = perp, random_state = 123)
    x3 = tsne.fit_transform(df_pca[['principal_component_1', 'principal_component_2']])
    ax[i].scatter(x3[:, 0], x3[:, 1], c = color_asign)
    ax[i].set_title(f'Perplexity = {perp}')
plt.show()
