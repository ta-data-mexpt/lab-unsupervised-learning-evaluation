# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import AgglomerativeClustering
from sklearn.decomposition import PCA
from sklearn.manifold  import TSNE

# %%
from sklearn.cluster import KMeans

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %%
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Length: 178, dtype: int32

# %%
print(data.DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
# ...

# %%
X.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
X.corr()
# Out:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
#
#                               alcalinity_of_ash  magnesium  total_phenols  \
# ...

# %%
sns.heatmap(X.corr(method='spearman'), cmap='coolwarm')

#sns.heatmap(main_df.iloc[:,[2, 4, 7, 9, 12, 13,14, 17,19]].corr(method='spearman') ,cmap='coolwarm')

# %%
X.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000014558148708>,
# ...
#       dtype=object)

# %%
X.boxplot();  ### No se requiere quitar outliers   Pero si es necesario el escalamiento

# %%
#hacemos unnuevo data frame escalado

from  sklearn.preprocessing import StandardScaler

s_scaler=StandardScaler()

x_scaled = s_scaler.fit_transform(X)  # hacemos fit transform con standard scaled, genera un conjunto denumpy arrays

X_working = pd.DataFrame(x_scaled, columns=data["feature_names"])  # creamos el data frame combinando los numpy arrays con los features names del load desklearn


X_working
# Out:
#       alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0    1.518613   -0.562250  0.232053          -1.169593   1.913905
# 1    0.246290   -0.499413 -0.827996          -2.490847   0.018145
# 2    0.196879    0.021231  1.109334          -0.268738   0.088358
# 3    1.691550   -0.346811  0.487926          -0.809251   0.930918
# 4    0.295700    0.227694  1.840403           0.451946   1.281985
# ..        ...         ...       ...                ...        ...
# 173  0.876275    2.974543  0.305159           0.301803  -0.332922
# 174  0.493343    1.412609  0.414820           1.052516   0.158572
# 175  0.332758    1.744744 -0.389355           0.151661   1.422412
# 176  0.209232    0.227694  0.012732           0.151661   1.422412
# 177  1.395086    1.583165  1.365208           1.502943  -0.262708
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0         0.808997    1.034819             -0.659563         1.224884
# ...

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmodel = KMeans(n_clusters=5)
kmodel.fit(X_working)

sil_score = metrics.silhouette_score(X_working, kmodel.labels_, metric = 'euclidean')


print(sil_score)
# Out:
# 0.22598380172332858

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmodel = KMeans(n_clusters=3)
kmodel.fit(X_working)

sil_score = metrics.silhouette_score(X_working, kmodel.labels_, metric = 'euclidean')


print(sil_score)
# Out:
# 0.2848589191898987

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
k_model = KMeans()
visualizer = KElbowVisualizer(k_model, k=(4,12))
visualizer.fit(X_working)
visualizer.poof()

# %%
k_model = KMeans()
visualizer = KElbowVisualizer(k_model, k=(4,12))
visualizer.fit(X)
visualizer.poof()

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
kmodel = AgglomerativeClustering()
visualizer = KElbowVisualizer(kmodel, k=(3,12))
visualizer.fit(X)
visualizer.poof();

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
df = X

k_model=KMeans(n_clusters = 6)

k_model.fit(df)

df['labels'] = k_model.labels_

sns.pairplot(data=df, hue='labels')

# %%
df = X_working

k_model = KMeans(n_clusters = 6)

k_model.fit(df.iloc[:,:-1])

df['labels'] = k_model.labels_

sns.pairplot(data=df, hue='labels')

# pendiente revisar causa del error
# Out:
# C:\Users\User\ANACONDA3.7\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\ANACONDA3.7\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\ANACONDA3.7\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\ANACONDA3.7\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
X_working.drop(columns='Labels', inplace=True)
X_working
# Out:
#       alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0    1.518613   -0.562250  0.232053          -1.169593   1.913905
# 1    0.246290   -0.499413 -0.827996          -2.490847   0.018145
# 2    0.196879    0.021231  1.109334          -0.268738   0.088358
# 3    1.691550   -0.346811  0.487926          -0.809251   0.930918
# 4    0.295700    0.227694  1.840403           0.451946   1.281985
# ..        ...         ...       ...                ...        ...
# 173  0.876275    2.974543  0.305159           0.301803  -0.332922
# 174  0.493343    1.412609  0.414820           1.052516   0.158572
# 175  0.332758    1.744744 -0.389355           0.151661   1.422412
# 176  0.209232    0.227694  0.012732           0.151661   1.422412
# 177  1.395086    1.583165  1.365208           1.502943  -0.262708
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0         0.808997    1.034819             -0.659563         1.224884
# ...

# %%
pca = PCA()
pca.n_components = 2 #only 2 principal components, as stated by the challenge


pca_data = pca.fit_transform(X.iloc[:,:-1]) #quitamos la columna de labels
#creamos df con los componentes de pcs
df_pca= pd.DataFrame(data = pca_data , columns = ['pc_1', 'pc_2'])

# %%
df_pca
# Out:
#            pc_1       pc_2
# 0    318.562979  21.492131
# 1    303.097420  -5.364718
# 2    438.061133  -6.537309
# 3    733.240139   0.192729
# 4    -11.571428  18.489995
# ..          ...        ...
# 173   -6.980211  -4.541137
# 174    3.131605   2.335191
# 175   88.458074  18.776285
# 176   93.456242  18.670819
# 177 -186.943190  -0.213331
#
# [178 rows x 2 columns]

# %%
sns.scatterplot(df_pca['pc_1'], df_pca['pc_2'], hue=k_model.labels_, palette = 'deep')

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
fig, ax = plt.subplots(1, 4, figsize = ( 15, 7))

for i, perp in enumerate([5, 30, 50, 100]):
    tsne = TSNE(perplexity=perp)
    x_embedded = tsne.fit_transform(X)
    ax[i].scatter(x_embedded[:, 0], x_embedded[:, 1], c=y)
    ax[i].set_title("Perplexity = {}".format(perp))
    
plt.show()

# %%
fig, ax = plt.subplots(1, 4, figsize = ( 15, 7))

for i, perp in enumerate([5, 30, 50, 100]):
    tsne = TSNE(perplexity=perp)
    x_embedded = tsne.fit_transform(X_working)
    ax[i].scatter(x_embedded[:, 0], x_embedded[:, 1], c=y)
    ax[i].set_title("Perplexity = {}".format(perp))
    
plt.show()

# %%
fig, ax = plt.subplots(1, 4, figsize = ( 15, 7))

for i, perp in enumerate([5, 30, 50, 100]):
    tsne = TSNE(perplexity=perp)
    x_embedded = tsne.fit_transform(df_pca)
    ax[i].scatter(x_embedded[:, 0], x_embedded[:, 1], c=y)
    ax[i].set_title("Perplexity = {}".format(perp))
    
plt.show()
