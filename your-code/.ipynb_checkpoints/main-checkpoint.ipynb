# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %%
X.head(3)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0

# %%
y.unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=8)
kmeans.fit(X)

#Pasamos nuestro dataset, nuestros clusters,nuestra metrida/meduida,tamaño de la muestra para el score
silhouette_score(X,kmeans.labels_,metric='euclidean',sample_size=len(X))
# Out:
# 0.5398971441034137

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans=KMeans(n_clusters=5)
kmeans.fit(X)

#Pasamos nuestro dataset, nuestros clusters,nuestra metrida/meduida,tamaño de la muestra para el score
silhouette_score(X,kmeans.labels_,metric='euclidean',sample_size=len(X))
# Out:
# 0.548999323979569

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans=KMeans(n_clusters=3)
kmeans.fit(X)

#Pasamos nuestro dataset, nuestros clusters,nuestra metrida/meduida,tamaño de la muestra para el score
silhouette_score(X,kmeans.labels_,metric='euclidean',sample_size=len(X))
# Out:
# 0.5711381937868844

# %%
# EL óptimo parece ser 3!

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from sklearn.datasets import make_blobs
from yellowbrick.cluster import KElbowVisualizer

# %%
# El elbow method por suma de cuadrados que vimos en clase

Sum_of_squared_distances = []
K = range(1,10)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(X)
    Sum_of_squared_distances.append(km.inertia_)
plt.figure(figsize=(15,5))
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
# Aun parece que el óptimo es 3 (aunque podríamos extendernos hasta 4)

# %%
# Silhouete sugiere que deben ser 6

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(
    model, k=(3,12), metric='silhouette', timings=False,locate_elbow=True)

plt.figure(figsize=(15,5))
visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
# Distortion sugiere que deben ser 5

model = KMeans()
visualizer = KElbowVisualizer(
    model, k=(3,12), metric='distortion', timings=False)

plt.figure(figsize=(15,5))
visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
# Calinski sugiere que deben ser 4

model = KMeans()
visualizer = KElbowVisualizer(
    model, k=(3,12), metric='calinski_harabasz', timings=False)

plt.figure(figsize=(15,5))
visualizer.fit(X)        
visualizer.show()

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
# Silhouete sugiere que deben ser 7

# Instantiate the clustering model and visualizer
model = AgglomerativeClustering()
visualizer = KElbowVisualizer(
    model, k=(3,12), metric='silhouette', timings=False,locate_elbow=True)

plt.figure(figsize=(15,5))
visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
# Distortion sugiere que deben ser 6

model = AgglomerativeClustering()
visualizer = KElbowVisualizer(
    model, k=(3,12), metric='distortion', timings=False)

plt.figure(figsize=(15,5))
visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
# Calinski sugiere que deben ser 4

model = AgglomerativeClustering()
visualizer = KElbowVisualizer(
    model, k=(3,12), metric='calinski_harabasz', timings=False)

plt.figure(figsize=(15,5))
visualizer.fit(X)        
visualizer.show()

# %%
# Tomaré 4 clusters por que es el más cercano a lo que habíamos consideradoo de manera inicial con el
# silhouette score y el Elbow method

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
from matplotlib.lines import Line2D
import seaborn as sns
from sklearn import cluster, datasets

# %%
# Realizamos la clusterización por kmeans
kmeans = cluster.KMeans(n_clusters=4)
kmeans.fit(X)

# Predicción
y2_pred = kmeans.predict(X)

# %%
# Ahora sí graficamos los scatterplots con diferenciación con la predicción

X['prediction']=y
sns.pairplot(data=X,kind='scatter', hue='prediction');

# %%
X=X.drop('prediction',axis=1)

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
standardized_data = StandardScaler().fit_transform(data.data)

# PCA
pca=PCA()
sample_data=standardized_data
pca.n_components = 2
pca_data = pca.fit_transform(sample_data)

#varianza explicada
percentage_var_explained = pca.explained_variance_ / np.sum(pca.explained_variance_);

#varianza explicada acumuladoata
cum_var_explained = np.cumsum(percentage_var_explained)

# Ploteamos la informacion
plt.figure(1, figsize=(6, 4))
plt.plot(cum_var_explained, linewidth=2)
plt.grid()
plt.xlabel('n_components')
plt.ylabel('Cumulative_explained_variance')
plt.show()

# %%
pca.n_components = 2
#Aplicamos la transformacion a nuestros datos
pca_data = pca.fit_transform(sample_data)
#creamos df con los componentes de pcs
df_pca= pd.DataFrame(data = pca_data , columns = ['PC1', 'PC2'])

df_pca_comp = pd.DataFrame(data=pca.components_,  columns = X.columns.values,index = ['PC1', 'PC2'])
df_pca_comp
# Out:
#       alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# PC1  0.144329   -0.245188 -0.002051          -0.239320   0.141992
# PC2 -0.483652   -0.224931 -0.316069           0.010591  -0.299634
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# PC1       0.394661    0.422934             -0.298533         0.313429
# PC2      -0.065040    0.003360             -0.028779        -0.039302
#
#      color_intensity       hue  od280/od315_of_diluted_wines   proline
# PC1        -0.088617  0.296715                      0.376167  0.286752
# PC2        -0.529996  0.279235                      0.164496 -0.364903

# %%
sns.heatmap(df_pca_comp,
            vmin = -1,
            vmax = 1,
            cmap='RdBu',
            annot=True
            )

plt.yticks([0,1,2],
           ['PC1', 'PC2']);

# %%
#Concatenar los componentes a los targets por nuestros 2 componentes
df_pred = pd.concat([df_pca,y],axis=1)

# %%
# Creamos el plot

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('PC1', fontsize = 10)
ax.set_ylabel('PC2', fontsize = 10)
ax.set_title('2 component PCA', fontsize = 15)

colors = ['r', 'green', 'b']
targets=[0,1,2]

for target, color in zip(targets,colors):
    indices_targets = df_pred[0] == target
    ax.scatter(df_pred.loc[indices_targets, 'PC1'], df_pred.loc[indices_targets, 'PC2'], c = color, s = 50)
    
ax.legend(targets)
ax.grid()

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
from sklearn.manifold  import TSNE

# %%
# Para que ya pueda colocar el color similar al PCA
df_pred.loc[df_pred[0] ==0, 'Color'] = 'r'
df_pred.loc[df_pred[0] ==1, 'Color'] = 'green'
df_pred.loc[df_pred[0] ==2, 'Color'] = 'b'

# %%
fig, ax = plt.subplots(1,4,figsize=(15,7))

for i, perp in enumerate([5,15,25,50]):
  #Perplejidad determina que tan amplio o estrecho es un espacio en t-sne que captura la similitues de los grupos.
  #Si la perplejidad es baja (2), tsne solo usara dos puntos similares y mostrara un grafico dispoerto.
  #Por lo general, se establece entre 5 y 50 
    tsne=TSNE(perplexity=perp,random_state=123)
    x_unida=tsne.fit_transform(df_pred[['PC1', 'PC2']])
    ax[i].scatter(x_unida[:,0],x_unida[:,1],c=df_pred['Color'])
    ax[i].set_title('Perplexity={}'.format(perp))

plt.show()
