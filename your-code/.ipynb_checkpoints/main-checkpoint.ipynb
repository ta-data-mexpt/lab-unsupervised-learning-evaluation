# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %%
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

kmeans = KMeans(n_clusters=8)
kmeans.fit(X)
s_score = silhouette_score(X, kmeans.labels_, metric='euclidean')
s_score
# Out:
# 0.5398971441034137

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
s_score = silhouette_score(X, kmeans.labels_, metric='euclidean')
s_score
# Out:
# 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
s_score = silhouette_score(X, kmeans.labels_, metric='euclidean')
s_score
# Out:
# 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import KElbowVisualizer
kmeans=KMeans()

visualizer=KElbowVisualizer(kmeans,k=(3,8))
visualizer.fit(X)
visualizer.poof();

# %%
kmeans=KMeans()
visualizer=KElbowVisualizer(kmeans,metric='silhouette',k=(3,8))
visualizer.fit(X)
visualizer.poof();

# %%
kmeans = KMeans()
visualizer = KElbowVisualizer(kmeans, metric='calinski_harabasz', k=(3,8))
visualizer.fit(X)
visualizer.poof();

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
from sklearn.cluster import AgglomerativeClustering

agglo = AgglomerativeClustering(n_clusters=8)
agglo.fit(X)

s_score = silhouette_score(X, agglo.labels_, metric='euclidean')
s_score
# Out:
# 0.5299175684221904

# %%
agglo = AgglomerativeClustering(n_clusters=5)
agglo.fit(X)

s_score = silhouette_score(X, agglo.labels_, metric='euclidean')
s_score
# Out:
# 0.5074843044233799

# %%
agglo = AgglomerativeClustering(n_clusters=3)
agglo.fit(X)

s_score = silhouette_score(X, agglo.labels_, metric='euclidean')
s_score
# Out:
# 0.5644796401732074

# %%
agglo = AgglomerativeClustering()
visualizer = KElbowVisualizer(agglo, k=(3,8))
visualizer.fit(X)
visualizer.poof();

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_pred = kmeans.predict(X)

plt.figure(figsize=(10,6))
plt.scatter(np.array(X)[:,0], np.array(X)[:,1], c=y_pred, cmap="viridis_r") 
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='r', s=120, alpha=0.9)


plt.show();

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(X)
pca_X = pca.transform(X)

fig=plt.figure(figsize=(12,6))
ax=[plt.subplot2grid((6,1),(0,0),rowspan=5)]

ax[0].scatter(pca_X[:,0],pca_X[:,1])
ax[0].set_xlabel('PCA 1')
ax[0].set_ylabel('PCA 2')

y=np.ones(X.shape[0])
plt.show()

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
import seaborn as sns
from sklearn.manifold import TSNE

fig, ax = plt.subplots(1, 4, figsize=(12, 5))
for i, perplex in enumerate([2,3,5,20]):
    tsne = TSNE(perplexity=perplex)
    x_embedded = tsne.fit_transform(X)
    ax[i].scatter(x_embedded[:, 0], x_embedded[:, 1], c=y)
    ax[i].set_title("Perplexity = {}".format(perplex))
    
plt.show();

# %%
pca_X[:,1]
# Out:
# array([ 21.49213073,  -5.36471768,  -6.53730945,   0.19272903,
#         18.48999461,  -0.33215867, -13.51896664,  11.44943238,
#         -8.18015784,  -7.10154294,  -8.33431723, -14.28763377,
#        -21.00501433, -16.10263522, -12.11844719,   2.21482866,
#         10.80480223,   8.47741982,  -8.35447844,  14.39265941,
#         25.5679565 ,   1.81747309,  -3.96304175,  -9.57070401,
#         -5.49584606,  22.89162155, -14.79733125, -15.38834607,
#          4.25531096,  -8.95973155,  -8.21273882,  -7.37989737,
#         -0.14391493,  23.56532504,   4.03808015,  -2.79292165,
#          7.77272958,  -8.15798412,  -6.72507431,  27.84683215,
#         16.32194976, -14.88511854,  -5.04342609,   4.38482992,
#          4.73068836,   5.31933116,  -3.48694494,  -3.051521  ,
#         -2.30536316,  -0.86375924, -15.05330285, -14.99755489,
#          3.26050204,   4.04114538,  12.60891351,   9.66419863,
#         14.21689241,  -7.09662526,  -1.35678013,  -7.99496797,
# ...
